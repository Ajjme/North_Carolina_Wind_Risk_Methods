tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201205.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201206.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201207.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201208.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201209.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201210.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201211.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201212.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201301.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201302.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201303.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201304.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201305.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201306.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201307.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201308.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201309.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201310.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201311.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201312.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201401.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201402.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201403.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201404.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201405.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201406.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201407.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201408.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201409.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201410.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201411.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201412.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201501.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201502.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201503.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201504.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201505.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201506.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201507.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201508.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201509.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201510.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201511.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201512.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201601.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201602.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201603.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201604.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201605.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201606.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201607.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201608.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201609.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201610.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201611.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201612.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201701.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201702.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201703.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201704.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201705.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201706.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201707.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201708.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201709.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201710.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201711.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201712.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201801.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201802.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201803.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201804.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201805.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201806.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201807.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201808.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201809.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201810.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201811.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201812.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201901.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201902.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201903.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201904.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201905.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201906.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201907.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201908.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201909.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201910.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201911.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201912.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202001.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202002.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202003.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202004.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202005.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202006.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202007.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202008.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202009.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202010.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202011.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202012.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202101.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202102.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202103.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202104.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202105.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202106.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202107.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202108.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202109.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202110.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202111.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202112.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202201.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202202.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202203.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202204.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202205.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202206.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202207.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202208.tar",
 "https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.202209.tar",
 ]

# %% [markdown]
# Change the value of `save_dir` if you prefer your files saved somewhere other than the current directory.

# %%
save_dir = 'ncar_data/'

# %% [markdown]
#  ## Now to download the files

# %%
filename
# Out:
# 'ncar_data/766933.SRH01uv.197911.tar'

# %%
file[-25:]
# Out:
# '766933.SRH01uv.197910.tar'

# %%
filelist[420:]
# Out:
# ['https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201410.tar',
#  'https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201411.tar',
#  'https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201412.tar',
#  'https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201501.tar',
#  'https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201502.tar',
#  'https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201503.tar',
#  'https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201504.tar',
#  'https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201505.tar',
#  'https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201506.tar',
#  'https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201507.tar',
#  'https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201508.tar',
#  'https://request.rda.ucar.edu/dsrqst/JOHNSON766933/766933.SRH01uv.201509.tar',
# ...

# %%
for file in filelist[465:]:
    filename = os.path.join(save_dir, os.path.basename(file[-25:]))
    print("Downloading", file)
    req = requests.get(file, allow_redirects=True)
    with open(filename, 'wb') as f:
        f.write(req.content)

# %% [markdown]
# ### Once you have downloaded the data, the next part can help you plot it.

# %% [markdown]
# In order to plot this data, you may need to install some libraries. The easiest way to do this is to use conda or pip, however any method of getting the following libraries will work.

# %%
import xarray # used for reading the data.
import matplotlib.pyplot as plt # used to plot the data.
import ipywidgets as widgets # For ease in selecting variables.
import cartopy.crs as ccrs # Used to georeference data.

# %%
filelist_arr = [save_dir + os.path.basename(file) for file in filelist]
selected_file = widgets.Dropdown(options=filelist_arr, description='data file')
display(selected_file)
# Out:
# Dropdown(description='data file', options=('ncar_data/766933.SRH01uv.197910.tar', 'ncar_data/766933.SRH01uv.19…

# %%
# Now to load in the data to xarray
ds = xarray.open_dataset(selected_file.value)

# %%
# Helper methods# Define function to get standard dimensions
def get_primary(dataset):
    primary_variables = {}
    coords = dataset.coords.keys()
    highest_dims = 0
    for cur_key,cur_var in dataset.variables.items():
        if cur_key not in coords:
            primary_variables[cur_key] = cur_var
    return primary_variables

# %%
var = widgets.Dropdown(
    options=get_primary(ds).keys(),
    description='Variable')
display(var)

# %%
proj = ccrs.Mercator()
plt.gcf().set_size_inches(20,10)
ax = plt.axes(projection=proj)
data_slice = ds[var.value].isel(time=0)
data_slice.plot.contourf(ax=ax, transform=ccrs.PlateCarree())
ax.set_global()
ax.coastlines()
